# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
emotions = ['admiration', 'amusement', 'anger', 'annoyance', 'approval', 'caring', 'confusion', 'curiosity', 'desire', 'disappointment', 'disapproval',
            'disgust', 'embarassment', 'excitement', 'fear', 'gratitude', 'grief', 'joy', 'love', 'nervousness', 'optimism', 'pride', 'realization', 'relief',
            'remorse', 'sadness', 'surprise', 'neutral']

results = pd.read_csv('SportSentiment_merged_output_2nd.csv')
#results2 = pd.read_csv('SportSentiment_merged_output_2nd.csv')

for ind in results.index:
  results['predicted_emotion'][ind] = emotions[results['predicted_emotion'][ind]]
  results['predicted_emotion_2nd'][ind] = emotions[results['predicted_emotion_2nd'][ind]]


relevant = results[['sport', 'category', 'predicted_emotion', 'predicted_emotion_2nd']]
relevant.head()
# Out:
# <ipython-input-6-171208cdaa31>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['predicted_emotion'][ind] = emotions[results['predicted_emotion'][ind]]
# <ipython-input-6-171208cdaa31>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['predicted_emotion_2nd'][ind] = emotions[results['predicted_emotion_2nd'][ind]]
#       sport category predicted_emotion predicted_emotion_2nd
# 0  Football       1N           neutral             annoyance
# 1  Football       1N             anger             annoyance
# 2  Football       1U             anger                  fear
# ...

# %%
favored_1 = relevant[relevant['category'].isin(['1F'])][['category', 'predicted_emotion']]
favored_2 = relevant[relevant['category'].isin(['2F'])][['category', 'predicted_emotion']]
favored_3 = relevant[relevant['category'].isin(['3F'])][['category', 'predicted_emotion']]
favored_4 = relevant[relevant['category'].isin(['4F'])][['category', 'predicted_emotion']]

favored_1 = favored_1.reset_index(drop=True)
favored_2 = favored_2.reset_index(drop=True)
favored_3 = favored_3.reset_index(drop=True)
favored_4 = favored_4.reset_index(drop=True)

#favored_1 = favored_1.to_frame()
#favored_2 = favored_2.to_frame()
#favored_3 = favored_3.to_frame()
#favored_4 = favored_4.to_frame()

#favored_1 = favored_1.rename(columns={"predicted_emotion": "1F"})
#favored_2 = favored_2.rename(columns={"predicted_emotion": "2F"})
#favored_3 = favored_3.rename(columns={"predicted_emotion": "3F"})
#favored_4 = favored_4.rename(columns={"predicted_emotion": "4F"})

#favored = pd.concat([favored_1, favored_2, favored_3, favored_4], ignore_index = True)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.set_figheight(18)
fig.set_figwidth(10)
fig.suptitle("Predicted Emotions of Favored Team Supporters", x=0.5, y=0.92)
#plt.tight_layout()

favored_1["predicted_emotion"].value_counts().plot(ax = ax1, kind="bar", title="1F")
favored_2["predicted_emotion"].value_counts().plot(ax = ax2, kind="bar", title="2F")
favored_3["predicted_emotion"].value_counts().plot(ax = ax3, kind="bar", title="3F")
favored_4["predicted_emotion"].value_counts().plot(ax = ax4, kind="bar", title="4F")

plt.show()

# %%
favored_1 = relevant[relevant['category'].isin(['1F'])][['category', 'predicted_emotion', 'predicted_emotion_2nd']]
favored_2 = relevant[relevant['category'].isin(['2F'])][['category', 'predicted_emotion', 'predicted_emotion_2nd']]
favored_3 = relevant[relevant['category'].isin(['3F'])][['category', 'predicted_emotion', 'predicted_emotion_2nd']]
favored_4 = relevant[relevant['category'].isin(['4F'])][['category', 'predicted_emotion', 'predicted_emotion_2nd']]

favored_1 = favored_1.reset_index(drop=True)
favored_2 = favored_2.reset_index(drop=True)
favored_3 = favored_3.reset_index(drop=True)
favored_4 = favored_4.reset_index(drop=True)

#favored_1 = favored_1.to_frame()
#favored_2 = favored_2.to_frame()
#favored_3 = favored_3.to_frame()
#favored_4 = favored_4.to_frame()

#favored_1 = favored_1.rename(columns={"predicted_emotion": "1F"})
#favored_2 = favored_2.rename(columns={"predicted_emotion": "2F"})
#favored_3 = favored_3.rename(columns={"predicted_emotion": "3F"})
#favored_4 = favored_4.rename(columns={"predicted_emotion": "4F"})

#favored = pd.concat([favored_1, favored_2, favored_3, favored_4], ignore_index = True)

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)
fig.set_figheight(18)
fig.set_figwidth(19)
fig.suptitle("Predicted Primary Emotions of Favored Team Supporters", x=0.50, y=0.92)
#plt.tight_layout()

favored_1["predicted_emotion"].value_counts().plot(ax = ax1, kind="bar", title="1F")
favored_2["predicted_emotion"].value_counts().plot(ax = ax2, kind="bar", title="2F")
favored_3["predicted_emotion"].value_counts().plot(ax = ax3, kind="bar", title="3F")
favored_4["predicted_emotion"].value_counts().plot(ax = ax4, kind="bar", title="4F")
favored_1["predicted_emotion_2nd"].value_counts().plot(ax = ax1, kind="bar")
favored_2["predicted_emotion_2nd"].value_counts().plot(ax = ax2, kind="bar")
favored_3["predicted_emotion_2nd"].value_counts().plot(ax = ax3, kind="bar")
favored_4["predicted_emotion_2nd"].value_counts().plot(ax = ax4, kind="bar")

plt.show()
fig.savefig("1F_Primary.jpg")

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-313663ead151> in <cell line: 5>()
#       3 second_dimension = "category"
#       4
# ----> 5 sns.histplot(binwidth=1,
#       6             x=first_dimension,
#       7             hue=second_dimension,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1393 ):
#    1394
# -> 1395     p = _DistributionPlotter(
#    1396         data=data,
#    1397         variables=_DistributionPlotter.get_semantics(locals())
#
# ...
